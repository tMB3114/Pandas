# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading data into Pandas

# %%
df = pd.read_csv('medical-examination.csv')

# %%
# show first 4 data
df.head(4)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1

# %%
# show last 4 data
df.tail(4)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
# show the shape of the data
df.shape
# Out:
# (70000, 13)

# %%
# set id as the index
#df = df.set_index('id')

# %%
# show the columns name
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
# read each columns
df['age'] # can use df.age
# Out:
# 0        18393
# 1        20228
# 2        18857
# 3        17623
# 4        17474
#          ...
# 69995    19240
# 69996    22601
# 69997    19066
# 69998    22431
# 69999    20540
# Name: age, Length: 70000, dtype: int64

# %%
# read multiple columns
df[['age','gender']].head(1)
# Out:
#      age  gender
# 0  18393       2

# %%
# show the datatype of the columns
df.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
# to show the details of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
# id             70000 non-null int64
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
# to count the number of null value
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# ### read each row

# %%
df.iloc[0:3,:].head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1

# %%
# lets print first row
df.loc[0,:]
# Out:
# id                 0.0
# age            18393.0
# gender             2.0
# height           168.0
# weight            62.0
# ap_hi            110.0
# ap_lo             80.0
# cholesterol        1.0
# gluc               1.0
# smoke              0.0
# alco               0.0
# active             1.0
# cardio             0.0
# Name: 0, dtype: float64

# %%
# lets access to height 165 of third columns
df.loc[2,'height'] # or df.iloc[2,3]
# Out:
# 165

# %%
df.iloc[2,3]
# Out:
# 165

# %% [markdown]
# ## create new column

# %%
df['Heights(M)'] = df['height'] / 100

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  Heights(M)
# 0     0       1       0        1.68
# 1     0       1       1        1.56
# 2     0       0       1        1.65
# 3     0       1       1        1.69
# 4     0       0       0        1.56

# %%
# lets remove the column height for the dataset
df.drop('height', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    id    age  gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   0  18393       2    62.0    110     80            1     1      0     0
# 1   1  20228       1    85.0    140     90            3     1      0     0
# 2   2  18857       1    64.0    130     70            3     1      0     0
# 3   3  17623       2    82.0    150    100            1     1      0     0
# 4   4  17474       1    56.0    100     60            1     1      0     0
#
#    active  cardio  Heights(M)
# 0       1       0        1.68
# 1       1       1        1.56
# 2       0       1        1.65
# 3       1       1        1.69
# 4       0       0        1.56

# %%
# lets change the gender column to M for male and f for female
df.loc[(df['gender'] == 2), 'gender'] = 'M'

# %%
df.loc[(df['gender'] == 1), 'gender'] = "F"

# %%
df.head()
# Out:
#    id    age gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   0  18393      M    62.0    110     80            1     1      0     0
# 1   1  20228      F    85.0    140     90            3     1      0     0
# 2   2  18857      F    64.0    130     70            3     1      0     0
# 3   3  17623      M    82.0    150    100            1     1      0     0
# 4   4  17474      F    56.0    100     60            1     1      0     0
#
#    active  cardio  Heights(M)
# 0       1       0        1.68
# 1       1       1        1.56
# 2       0       1        1.65
# 3       1       1        1.69
# 4       0       0        1.56

# %%
# lets change M to 1 and F to 0
df['gender'] = df['gender'].apply(lambda x: 0 if x == "F" else 1 )

# %%
df.head()
# Out:
#    id    age  gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   0  18393       1    62.0    110     80            1     1      0     0
# 1   1  20228       0    85.0    140     90            3     1      0     0
# 2   2  18857       0    64.0    130     70            3     1      0     0
# 3   3  17623       1    82.0    150    100            1     1      0     0
# 4   4  17474       0    56.0    100     60            1     1      0     0
#
#    active  cardio  Heights(M)
# 0       1       0        1.68
# 1       1       1        1.56
# 2       0       1        1.65
# 3       1       1        1.69
# 4       0       0        1.56

# %%
df.head()
# Out:
#    id    age  gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   0  18393       1    62.0    110     80            1     1      0     0
# 1   1  20228       0    85.0    140     90            3     1      0     0
# 2   2  18857       0    64.0    130     70            3     1      0     0
# 3   3  17623       1    82.0    150    100            1     1      0     0
# 4   4  17474       0    56.0    100     60            1     1      0     0
#
#    active  cardio  Heights(M)
# 0       1       0        1.68
# 1       1       1        1.56
# 2       0       1        1.65
# 3       1       1        1.69
# 4       0       0        1.56

# %%
# lets analyze age ,,, lets take only last two digits of the age 
df['age'] = df['age'] % 100

# %%
df.head()
# Out:
#    id  age  gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   0   93       1    62.0    110     80            1     1      0     0
# 1   1   28       0    85.0    140     90            3     1      0     0
# 2   2   57       0    64.0    130     70            3     1      0     0
# 3   3   23       1    82.0    150    100            1     1      0     0
# 4   4   74       0    56.0    100     60            1     1      0     0
#
#    active  cardio  Heights(M)
# 0       1       0        1.68
# 1       1       1        1.56
# 2       0       1        1.65
# 3       1       1        1.69
# 4       0       0        1.56

# %%
df
